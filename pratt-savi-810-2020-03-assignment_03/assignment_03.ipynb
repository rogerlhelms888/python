# %% [markdown]
# # Assignment 03
#
# # Exploratory Data Analysis (EDA)
#
#
# #### Bring your own Data and write your own code
#
# ![http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg](http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-03" data-toc-modified-id="Assignment-03-1">Assignment 03</a></span></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-2">Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Bring-your-own-Data-and-write-your-own-code" data-toc-modified-id="Bring-your-own-Data-and-write-your-own-code-2.0.0.1">Bring your own Data and write your own code</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-3">Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Bring-your-own-Data-and-write-your-own-code" data-toc-modified-id="Bring-your-own-Data-and-write-your-own-code-3.0.0.1">Bring your own Data and write your own code</a></span></li></ul></li></ul></li><li><span><a href="#Instructions" data-toc-modified-id="Instructions-3.1">Instructions</a></span></li><li><span><a href="#Due-Date-Monday-2020/04/13" data-toc-modified-id="Due-Date-Monday-2020/04/13-3.2">Due Date Monday 2020/04/13</a></span></li></ul></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-4">Import Libraries</a></span></li><li><span><a href="#1.-Find-some-spatial-Data" data-toc-modified-id="1.-Find-some-spatial-Data-5">1. Find some spatial Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Where-does-your-data-come-from?" data-toc-modified-id="Where-does-your-data-come-from?-5.0.1">Where does your data come from?</a></span></li><li><span><a href="#Describe-how-your-data-is-generated." data-toc-modified-id="Describe-how-your-data-is-generated.-5.0.2">Describe how your data is generated.</a></span></li><li><span><a href="#Why-did-you-choose-this-data-file?" data-toc-modified-id="Why-did-you-choose-this-data-file?-5.0.3">Why did you choose this data file?</a></span></li></ul></li></ul></li><li><span><a href="#2.-Load-in-your-Geospatial-Data-as-GeoDataFrame" data-toc-modified-id="2.-Load-in-your-Geospatial-Data-as-GeoDataFrame-6">2. Load in your Geospatial Data as GeoDataFrame</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Load-your-file-into-a-GeoDataFrame" data-toc-modified-id="Load-your-file-into-a-GeoDataFrame-6.0.0.1">Load your file into a GeoDataFrame</a></span></li><li><span><a href="#Show-the-head()-of-the-DataFrame" data-toc-modified-id="Show-the-head()-of-the-DataFrame-6.0.0.2">Show the <code>head(</code>) of the DataFrame</a></span></li><li><span><a href="#Show-the-tail()-of-the-DataFrame" data-toc-modified-id="Show-the-tail()-of-the-DataFrame-6.0.0.3">Show the <code>tail(</code>) of the DataFrame</a></span></li><li><span><a href="#(Optional)--Do-any-additional-or-other-Data-Exploration-or-Transformation-to-your-data-in-cell(s)-below;" data-toc-modified-id="(Optional)--Do-any-additional-or-other-Data-Exploration-or-Transformation-to-your-data-in-cell(s)-below;-6.0.0.4">(Optional)  Do any additional or other Data Exploration or Transformation to your data in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#3.-Exploratory-Data-Analysis-(EDA)-Plots" data-toc-modified-id="3.-Exploratory-Data-Analysis-(EDA)-Plots-7">3. Exploratory Data Analysis (EDA) Plots</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Plot-the-Distribution-of-one-of-your-data's-columns-in-a-Histogram-Plot-or-some-other-Matplotlib,-Seaborn,-Missingno-plot" data-toc-modified-id="Plot-the-Distribution-of-one-of-your-data's-columns-in-a-Histogram-Plot-or-some-other-Matplotlib,-Seaborn,-Missingno-plot-7.0.0.1">Plot the Distribution of one of your data's columns in a Histogram Plot or some other Matplotlib, Seaborn, Missingno plot</a></span></li><li><span><a href="#(Optional)-Do-any-additional-or-other-Plots-in-cell(s)-below;" data-toc-modified-id="(Optional)-Do-any-additional-or-other-Plots-in-cell(s)-below;-7.0.0.2">(Optional) Do any additional or other Plots in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#4.-Map-your-Data" data-toc-modified-id="4.-Map-your-Data-8">4. Map your Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Create-GeoDataFrame-Map--.plot()-to-see-our-the-spatial-distribution-of-your-data" data-toc-modified-id="Create-GeoDataFrame-Map--.plot()-to-see-our-the-spatial-distribution-of-your-data-8.0.0.1">Create GeoDataFrame Map  <code>.plot()</code> to see our the spatial distribution of your data</a></span></li><li><span><a href="#(Optional)-Do-any-additional-or-other-Maps-in-cell(s)-below;" data-toc-modified-id="(Optional)-Do-any-additional-or-other-Maps-in-cell(s)-below;-8.0.0.2">(Optional) Do any additional or other Maps in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#5.-Highlight-any-interesting-findings" data-toc-modified-id="5.-Highlight-any-interesting-findings-9">5. Highlight any interesting findings</a></span></li><li><span><a href="#6.-Present" data-toc-modified-id="6.-Present-10">6. Present</a></span></li></ul></div>

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
#
# #### Bring your own Data and write your own code
#
# ---
#
#
# ## Instructions
#
#
# Assignment 03 is fairly open-ended and you can do as much or as little as you like. However, you are **required** to do the following;
#
#
# 1. **Find** a geospatial data file
# 2. Read it in as a **GeoDataFrame**
# 3. **Perform** some **Exploratory Data Analysis** (EDA) by **creating some plots that describe your data**
#   - Perhaps plot a Histogram
#   - Perhaps plot a Bar Chart
#   - Perhaps plot a Scatterplot of two variables
# 4. **Plot a map**
#   - Required: A map title
#   - A larger than default `figsize`.
# 5. **Highlight any interesting findings**
#
# 6. **Present** your Exploratory Data Analysis to the class **Monday 2020/04/13**
#   - Required: Present your Notebook to the class - **5-7 minute presentation in class on Monday 2020/04/13**.
#   - No need for Powerpoint or Slides, **you'll present your Notebook**.
#
#
# **Optional**:
# You may choose to do the following tasks for more practice and deeper insights. I recommended doing one of the following;
#
# * Perform some Geoprocessing (Reprojection, Buffer, Centroid, Overlay (Intersection, etc)) and plot a map.
# * Thematically style your data map, i.e. a Choropleth, Graduate Symbol, etc.
#
# If you need some inspiration for data sources try:
#
# * [NYC Open Data](https://opendata.cityofnewyork.us/)
# * [NYS Open Data](https://data.ny.gov/)
# * [US Data.gov](https://www.data.gov/)
#
# Otherwise **bring your own data**. **Note:** if your data is medical or health patient data or business data where security is an issue, **DO NOT USE BUSINESS SENSITIVE OR Personally Identifiable Information (PII) data**. If you are not sure, ask me in Slack via a Direct Message.
#
# ## Due Date Monday 2020/04/13
#
# This Assignment 03 is **due Monday 2020/04/13**.
#
# You will be **presenting your Notebook to the class - 5-7 minute presentation in class on Monday 2020/04/13**.  No need for Powerpoint or Slides, you'll present your Notebook.

# %% [markdown]
# # Import Libraries
# The libraries required for this assignment are imported for you below.

# %%
import pandas as pd
import geopandas as gpd 
import numpy as np
import matplotlib.pyplot as plt

# add any additional libraries you need here

# %%
# %matplotlib inline
# run this cell

# %% [markdown]
# # 1. Find some spatial Data
#
# Add some text and links in the sections below.
#
# **IMPORTANT**: If your data file or any component files is greater than 50 MB - please talk to me about `.gitignore`-ing your data before you commit, push your notebook up to GitHub.

# %% [markdown]
# ### Where does your data come from?
#
# * **Data Name**: `Type in the official name of your data here, if its personal or professional data, create a name for your data`.
# * **Data Source Name**: `Type the name of the organization that created your data here`
# * **Data Source Link**: `<Paste a link to your data if on the internet, if not, leave empty>`

# %% [markdown]
# ### Describe how your data is generated.
#
# ```Your text describing your data here```

# %% [markdown]
# ### Why did you choose this data file?
#
# ```Your text describing your data here. Anything from, I'm required to explore this data for my job, I'm lazy and this was the first data I found, or I'm interested in the distribution of Motorcycle Repair shops, etc.```

# %% [markdown]
# # 2. Load in your Geospatial Data as GeoDataFrame

# %% [markdown]
# #### Load your file into a GeoDataFrame
# See **Lesson 03 GeoPandas section** for reference.
#
# You're being asking to load the GeoDataFrame as a variable named `gdf`.
#
# ```python
#
# gdf = # "read" the file
#
# ```

# %%
import pandas as pd  # import pandas
# ran successfully at 4/20/20

# %%
### your code here
# store the file path to a variable name:
my_CSV_path_name = r'C:\Users\Roger Helms\Documents\ArcGIS\Projects\ACLED\2019-01-01-2020-04-22-Afghanistan.csv'
# read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). 
# Don't forget to put the file name at the end of the path + ".csv"
# ran successfully at 4/22/20

# %%
### your code here
# open the .CSV file into a Pandas data frame ('df').
df = pd.read_csv(my_CSV_path_name, parse_dates=True)  #pd is the variable name of the imported pandas
# parse_dates="True" is supposed to date enable my event_date field, but doesn't seem to.
# ran successfully at 4/22/20

# %% [markdown]
# #### Show the `head(`) of the DataFrame

# %%
### your code here
df.head(3)
# ran successfully at 4/20/20
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty     event_date  year  \
# 0  7063086    4      AFG45190             45190  18 April 2020  2020
# 1  7063121    4      AFG45193             45193  18 April 2020  2020
# 2  7063203    4      AFG45196             45196  18 April 2020  2020
#
#    time_precision                  event_type    sub_event_type  \
# 0               2  Explosions/Remote violence  Air/drone strike
# 1               2                     Battles       Armed clash
# 2               1                     Battles       Armed clash
#
#                                    actor1  ... location  latitude longitude  \
# 0  Military Forces of Afghanistan (2014-)  ...   Charkh   33.7971   68.9375
# 1                                 Taliban  ...   Zurmat   33.4378   69.0277
# 2                                 Taliban  ...    Khash   31.5292   62.7905
#
#   geo_precision                               source     source_scale  \
# 0             2  Twitter; Afghan Ministry of Defense  Other-New media
# 1             2                         Khaama Press         National
# 2             2                  Pajhwok Afghan News         National
#
#                                                notes fatalities   timestamp  \
# 0  As reported on 18 April 2020, 10 Taliban milit...         10  1587405895
# 1  As reported on 18 April 2020, 6 Taliban milita...          6  1587405895
# 2  On 18 April 2020, 2 policemen and 2 Taliban mi...          4  1587405896
#
#   iso3
# 0  AFG
# 1  AFG
# 2  AFG
#
# [3 rows x 31 columns]

# %% [markdown]
# #### Show the `tail(`) of the DataFrame

# %%
### your code here
df.tail(3)
# ran successfully at 4/22/20
# 16000 rows
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 15998  6829309    4      AFG15849             15849  01 January 2019  2019
# 15999  6829310    4      AFG15839             15839  01 January 2019  2019
# 16000  6829311    4      AFG15841             15841  01 January 2019  2019
#
#        time_precision event_type sub_event_type  \
# 15998               2    Battles    Armed clash
# 15999               1    Battles    Armed clash
# 16000               1    Battles    Armed clash
#
#                                                   actor1  ...     location  \
# 15998  Police Forces of Afghanistan (2014-) Afghan Lo...  ...  Dashti Qala
# 15999             Military Forces of Afghanistan (2014-)  ...     Dur Baba
# 16000             Military Forces of Afghanistan (2014-)  ...        Rodat
#
#        latitude longitude geo_precision               source   source_scale  \
# 15998   37.2216   69.4975             2               Xinhua  International
# 15999   34.0397   70.9300             2  Bakhtar News Agency       National
# 16000   34.2720   70.5679             2  Bakhtar News Agency       National
#
#                                                    notes fatalities  \
# 15998  On 01-January-2019, it was reported that 2 Afg...          5
# 15999  On 01-January-2019, 13 Islamic State and Talib...          5
# 16000  On 01-January-2019, 13 Islamic State and Talib...          4
#
#         timestamp iso3
# 15998  1580846929  AFG
# 15999  1580846929  AFG
# 16000  1580846929  AFG
#
# [3 rows x 31 columns]

# %% [markdown]
# #### (Optional)  Do any additional or other Data Exploration or Transformation to your data in cell(s) below;

# %%
### your optional code here
# rows and columns
df.shape
# Out:
# (16001, 31)

# %%
# cast event_date, which is a string 'object' to a datetime format
df['event_date'] = pd.to_datetime(df['event_date'])
# ran successfully at 4/22/20  The dates now look good:
df.head(2)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  7063086    4      AFG45190             45190 2020-04-18  2020
# 1  7063121    4      AFG45193             45193 2020-04-18  2020
#
#    time_precision                  event_type    sub_event_type  \
# 0               2  Explosions/Remote violence  Air/drone strike
# 1               2                     Battles       Armed clash
#
#                                    actor1  ... location  latitude longitude  \
# 0  Military Forces of Afghanistan (2014-)  ...   Charkh   33.7971   68.9375
# 1                                 Taliban  ...   Zurmat   33.4378   69.0277
#
#   geo_precision                               source     source_scale  \
# 0             2  Twitter; Afghan Ministry of Defense  Other-New media
# 1             2                         Khaama Press         National
#
#                                                notes fatalities   timestamp  \
# 0  As reported on 18 April 2020, 10 Taliban milit...         10  1587405895
# 1  As reported on 18 April 2020, 6 Taliban milita...          6  1587405895
#
#   iso3
# 0  AFG
# 1  AFG
#
# [2 rows x 31 columns]

# %%
#  df.loc['2020-04-01 00:00:00','event_date'] # fails
# df.loc['01 January 2019','event_date'] # fails.  Perhaps because the event_date isn't the index.
# df.loc[7063121,'event_date'] 
df.['event_date']['7063121'] # fails
# Out:
#   File "<ipython-input-122-8c502c57d127>", line 4
#     df.['event_date']['7063121']
#        ^
# SyntaxError: invalid syntax

# %%
# subselect columns to show
df[['data_id','event_date','notes']].head(3)
# df[['data_id','event_date']].tail(3)
# Out:
#    data_id event_date                                              notes
# 0  7063086 2020-04-18  As reported on 18 April 2020, 10 Taliban milit...
# 1  7063121 2020-04-18  As reported on 18 April 2020, 6 Taliban milita...
# 2  7063203 2020-04-18  On 18 April 2020, 2 policemen and 2 Taliban mi...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16001 entries, 0 to 16000
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           16001 non-null  int64
#  1   iso               16001 non-null  int64
#  2   event_id_cnty     16001 non-null  object
#  3   event_id_no_cnty  16001 non-null  int64
#  4   event_date        16001 non-null  object
#  5   year              16001 non-null  int64
#  6   time_precision    16001 non-null  int64
#  7   event_type        16001 non-null  object
#  8   sub_event_type    16001 non-null  object
#  9   actor1            16001 non-null  object
#  10  assoc_actor_1     1134 non-null   object
#  11  inter1            16001 non-null  int64
#  12  actor2            15978 non-null  object
#  13  assoc_actor_2     982 non-null    object
#  14  inter2            16001 non-null  int64
#  15  interaction       16001 non-null  int64
#  16  region            16001 non-null  object
#  17  country           16001 non-null  object
#  18  admin1            16001 non-null  object
#  19  admin2            16001 non-null  object
#  20  admin3            0 non-null      float64
#  21  location          16001 non-null  object
#  22  latitude          16001 non-null  float64
#  23  longitude         16001 non-null  float64
#  24  geo_precision     16001 non-null  int64
#  25  source            16001 non-null  object
#  26  source_scale      16001 non-null  object
#  27  notes             16001 non-null  object
#  28  fatalities        16001 non-null  int64
#  29  timestamp         16001 non-null  int64
#  30  iso3              16001 non-null  object
# dtypes: float64(3), int64(11), object(17)
# memory usage: 3.8+ MB

# %%
# run canned stats on numeric fields (but no sum)
df.describe()
# Out:
#             data_id      iso  event_id_no_cnty          year  time_precision  \
# count  1.591900e+04  15919.0      15919.000000  15919.000000    15919.000000
# mean   6.839230e+06      4.0      26679.803694   2019.144796        1.143979
# std    5.257479e+04      0.0       9160.086361      0.351906        0.351258
# min    6.814496e+06      4.0      15834.000000   2019.000000        1.000000
# 25%    6.818778e+06      4.0      19904.500000   2019.000000        1.000000
# 50%    6.823010e+06      4.0      24020.000000   2019.000000        1.000000
# 75%    6.827192e+06      4.0      28282.500000   2019.000000        1.000000
# max    7.062222e+06      4.0      45115.000000   2020.000000        3.000000
#
#              inter1        inter2   interaction  admin3      latitude  \
# count  15919.000000  15919.000000  15919.000000     0.0  15919.000000
# mean       1.836610      1.953766     14.862994     NaN     33.937433
# std        1.149412      1.595830      8.907301     NaN      1.737713
# min        1.000000      0.000000     10.000000     NaN     29.730000
# 25%        1.000000      1.000000     12.000000     NaN     32.426900
# 50%        2.000000      1.000000     12.000000     NaN     33.791700
# 75%        2.000000      2.000000     12.000000     NaN     35.039700
# max        8.000000      8.000000     80.000000     NaN     38.443500
#
#           longitude  geo_precision    fatalities     timestamp
# count  15919.000000   15919.000000  15919.000000  1.591900e+04
# mean      67.092506       1.810164      2.882405  1.581256e+09
# std        2.472981       0.452986      5.818624  1.261332e+06
# min       61.066700       1.000000      0.000000  1.580847e+09
# 25%       65.096400       2.000000      0.000000  1.580847e+09
# 50%       67.269200       2.000000      0.000000  1.580847e+09
# 75%       69.099900       2.000000      4.000000  1.580847e+09
# max       71.547400       3.000000    165.000000  1.586901e+09

# %%
df['fatalities'].sum()
# Out:
# 46146

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA) Plots

# %% [markdown]
# #### Plot the Distribution of one of your data's columns in a Histogram Plot or some other Matplotlib, Seaborn, Missingno plot
# If you have a numerical column, otherwise plot a bar plot to show categorical counts.
#
# * Here's an code example for a bar plot - https://python-graph-gallery.com/1-basic-barplot

# %%
### your code here
### The goal is to plot events by day.
#   Create an index column
#   Group events by day.
#   Count events by day.
#   sum fatalities by day.

# %%
### your code here
#   Create an index col.
df.reset_index(inplace=True) # creates a numeric index

# ran successfully at 4/22/20

# %%
# cast event_date, which is a string 'object' to a datetime format
df['event_date'] = pd.to_datetime(df['event_date'])
# ran successfully at 4/22/20  The dates now look good:

# %%
df.head(6)
# Out:
#    index  data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0      0  7063086    4      AFG45190             45190 2020-04-18  2020
# 1      1  7063121    4      AFG45193             45193 2020-04-18  2020
# 2      2  7063203    4      AFG45196             45196 2020-04-18  2020
# 3      3  7063205    4      AFG45195             45195 2020-04-18  2020
# 4      4  7063238    4      AFG45189             45189 2020-04-18  2020
# 5      5  7063087    4      AFG45201             45201 2020-04-17  2020
#
#    time_precision                  event_type  \
# 0               2  Explosions/Remote violence
# 1               2                     Battles
# 2               1                     Battles
# 3               1                     Battles
# 4               2                     Battles
# 5               1  Violence against civilians
#
#                         sub_event_type  ...    location latitude  longitude  \
# 0                     Air/drone strike  ...      Charkh  33.7971    68.9375
# 1                          Armed clash  ...      Zurmat  33.4378    69.0277
# 2                          Armed clash  ...       Khash  31.5292    62.7905
# 3  Non-state actor overtakes territory  ...     Kotalak  31.8856    63.0866
# 4                          Armed clash  ...      Kunduz  36.7290    68.8570
# 5                               Attack  ...  Lashkargah  31.5938    64.3716
#
#   geo_precision                                             source  \
# 0             2                Twitter; Afghan Ministry of Defense
# 1             2                                       Khaama Press
# 2             2                                Pajhwok Afghan News
# 3             1                                Pajhwok Afghan News
# 4             1                                     Voice of Jihad
# 5             1  Xinhua; TOLO News; Afghan Islamic Press News A...
#
#              source_scale                                              notes  \
# 0         Other-New media  As reported on 18 April 2020, 10 Taliban milit...
# 1                National  As reported on 18 April 2020, 6 Taliban milita...
# 2                National  On 18 April 2020, 2 policemen and 2 Taliban mi...
# 3                National  On 18 April 2020, 2 soldiers and 2 Taliban mil...
# 4                   Other  As reported on 18 April 2020, 1 soldier was ki...
# 5  National-International  On 17 April 2020, the PD8 police chief (off-du...
#
#   fatalities   timestamp iso3
# 0         10  1587405895  AFG
# 1          6  1587405895  AFG
# 2          4  1587405896  AFG
# 3          4  1587405896  AFG
# 4          0  1587405896  AFG
# 5          2  1587405895  AFG
#
# [6 rows x 32 columns]

# %%
# cut the days down to the ones in 2019
rats_df=df.loc[:,'event_date':'fatalities']
# Out:
#       event_date  year  time_precision                  event_type  \
# 0     2020-04-18  2020               2  Explosions/Remote violence
# 1     2020-04-18  2020               2                     Battles
# 2     2020-04-18  2020               1                     Battles
# 3     2020-04-18  2020               1                     Battles
# 4     2020-04-18  2020               2                     Battles
# ...          ...   ...             ...                         ...
# 15996 2019-01-01  2019               1                     Battles
# 15997 2019-01-01  2019               1                     Battles
# 15998 2019-01-01  2019               2                     Battles
# 15999 2019-01-01  2019               1                     Battles
# 16000 2019-01-01  2019               1                     Battles
#
#                             sub_event_type  \
# 0                         Air/drone strike
# 1                              Armed clash
# 2                              Armed clash
# 3      Non-state actor overtakes territory
# 4                              Armed clash
# ...                                    ...
# 15996                          Armed clash
# 15997                          Armed clash
# 15998                          Armed clash
# 15999                          Armed clash
# 16000                          Armed clash
#
#                                                   actor1 assoc_actor_1  \
# 0                 Military Forces of Afghanistan (2014-)           NaN
# 1                                                Taliban           NaN
# 2                                                Taliban           NaN
# 3                                                Taliban           NaN
# 4                                                Taliban           NaN
# ...                                                  ...           ...
# 15996             Military Forces of Afghanistan (2014-)           NaN
# 15997             Military Forces of Afghanistan (2014-)           NaN
# 15998  Police Forces of Afghanistan (2014-) Afghan Lo...           NaN
# 15999             Military Forces of Afghanistan (2014-)           NaN
# 16000             Military Forces of Afghanistan (2014-)           NaN
#
#        inter1                                      actor2 assoc_actor_2  ...  \
# 0           1                                     Taliban           NaN  ...
# 1           2      Military Forces of Afghanistan (2014-)           NaN  ...
# 2           2        Police Forces of Afghanistan (2014-)           NaN  ...
# 3           2      Military Forces of Afghanistan (2014-)           NaN  ...
# 4           2      Military Forces of Afghanistan (2014-)           NaN  ...
# ...       ...                                         ...           ...  ...
# 15996       1  Taliban and/or Islamic State (Afghanistan)           NaN  ...
# 15997       1  Taliban and/or Islamic State (Afghanistan)           NaN  ...
# 15998       1                                     Taliban           NaN  ...
# 15999       1  Taliban and/or Islamic State (Afghanistan)           NaN  ...
# 16000       1  Taliban and/or Islamic State (Afghanistan)           NaN  ...
#
#             admin2  admin3     location latitude longitude geo_precision  \
# 0           Charkh     NaN       Charkh  33.7971   68.9375             2
# 1           Zurmat     NaN       Zurmat  33.4378   69.0277             2
# 2        Khash Rod     NaN        Khash  31.5292   62.7905             2
# 3        Khash Rod     NaN      Kotalak  31.8856   63.0866             1
# 4           Kunduz     NaN       Kunduz  36.7290   68.8570             1
# ...            ...     ...          ...      ...       ...           ...
# 15996    Khan Abad     NaN    Khan Abad  36.6830   69.1128             2
# 15997     Tarinkot     NaN    Khan Agha  32.6475   65.9407             1
# 15998  Dashti Qala     NaN  Dashti Qala  37.2216   69.4975             2
# 15999     Dur Baba     NaN     Dur Baba  34.0397   70.9300             2
# 16000        Rodat     NaN        Rodat  34.2720   70.5679             2
#
#                                     source     source_scale  \
# 0      Twitter; Afghan Ministry of Defense  Other-New media
# 1                             Khaama Press         National
# 2                      Pajhwok Afghan News         National
# 3                      Pajhwok Afghan News         National
# 4                           Voice of Jihad            Other
# ...                                    ...              ...
# 15996           Afghan Ministry of Defense            Other
# 15997           Afghan Ministry of Defense            Other
# 15998                               Xinhua    International
# 15999                  Bakhtar News Agency         National
# 16000                  Bakhtar News Agency         National
#
#                                                    notes  fatalities
# 0      As reported on 18 April 2020, 10 Taliban milit...          10
# 1      As reported on 18 April 2020, 6 Taliban milita...           6
# 2      On 18 April 2020, 2 policemen and 2 Taliban mi...           4
# 3      On 18 April 2020, 2 soldiers and 2 Taliban mil...           4
# 4      As reported on 18 April 2020, 1 soldier was ki...           0
# ...                                                  ...         ...
# 15996  As reported on Jan 2, over the past 24 hours, ...           2
# 15997  As reported on Jan 2, over the past 24 hours, ...           8
# 15998  On 01-January-2019, it was reported that 2 Afg...           5
# 15999  On 01-January-2019, 13 Islamic State and Talib...           5
# 16000  On 01-January-2019, 13 Islamic State and Talib...           4
#
# [16001 rows x 25 columns]

# %%
rats_df=df.loc[:,'event_date':'fatalities']

# %%
rats_df_2020=rats_df.loc[10000:16000,:]
rats_df_2020
# Out:
#       event_date  year  time_precision                  event_type  \
# 10000 2019-07-11  2019               2                     Battles
# 10001 2019-07-11  2019               2  Explosions/Remote violence
# 10002 2019-07-11  2019               2                     Battles
# 10003 2019-07-11  2019               1                     Battles
# 10004 2019-07-11  2019               1  Explosions/Remote violence
# ...          ...   ...             ...                         ...
# 15996 2019-01-01  2019               1                     Battles
# 15997 2019-01-01  2019               1                     Battles
# 15998 2019-01-01  2019               2                     Battles
# 15999 2019-01-01  2019               1                     Battles
# 16000 2019-01-01  2019               1                     Battles
#
#                       sub_event_type  \
# 10000                    Armed clash
# 10001  Remote explosive/landmine/IED
# 10002                    Armed clash
# 10003                    Armed clash
# 10004  Remote explosive/landmine/IED
# ...                              ...
# 15996                    Armed clash
# 15997                    Armed clash
# 15998                    Armed clash
# 15999                    Armed clash
# 16000                    Armed clash
#
#                                                   actor1 assoc_actor_1  \
# 10000                                            Taliban           NaN
# 10001                                            Taliban           NaN
# 10002                                            Taliban           NaN
# 10003                                            Taliban           NaN
# 10004             Unidentified Armed Group (Afghanistan)           NaN
# ...                                                  ...           ...
# 15996             Military Forces of Afghanistan (2014-)           NaN
# 15997             Military Forces of Afghanistan (2014-)           NaN
# 15998  Police Forces of Afghanistan (2014-) Afghan Lo...           NaN
# 15999             Military Forces of Afghanistan (2014-)           NaN
# 16000             Military Forces of Afghanistan (2014-)           NaN
#
#        inter1                                      actor2  \
# 10000       2      Military Forces of Afghanistan (2014-)
# 10001       2      Military Forces of Afghanistan (2014-)
# 10002       2      Military Forces of Afghanistan (2014-)
# 10003       2      Military Forces of Afghanistan (2014-)
# 10004       3        Police Forces of Afghanistan (2014-)
# ...       ...                                         ...
# 15996       1  Taliban and/or Islamic State (Afghanistan)
# 15997       1  Taliban and/or Islamic State (Afghanistan)
# 15998       1                                     Taliban
# 15999       1  Taliban and/or Islamic State (Afghanistan)
# 16000       1  Taliban and/or Islamic State (Afghanistan)
#
#                                assoc_actor_2  ...            admin2  admin3  \
# 10000                                    NaN  ...         Kohi Safi     NaN
# 10001                                    NaN  ...      Chaki Wardak     NaN
# 10002                                    NaN  ...          Qarghayi     NaN
# 10003  Private Security Forces (Afghanistan)  ...             Aqcha     NaN
# 10004                                    NaN  ...  Tarnak Wa Jaldak     NaN
# ...                                      ...  ...               ...     ...
# 15996                                    NaN  ...         Khan Abad     NaN
# 15997                                    NaN  ...          Tarinkot     NaN
# 15998                                    NaN  ...       Dashti Qala     NaN
# 15999                                    NaN  ...          Dur Baba     NaN
# 16000                                    NaN  ...             Rodat     NaN
#
#                location latitude longitude geo_precision  \
# 10000         Kohi Safi  34.7602   69.4686             2
# 10001      Chaki Wardak  34.1061   68.5794             2
# 10002       Lalkhanabad  34.5470   70.2444             2
# 10003             Aqcha  36.9050   66.1834             2
# 10004  Tarnak Wa Jaldak  31.9055   66.5167             2
# ...                 ...      ...       ...           ...
# 15996         Khan Abad  36.6830   69.1128             2
# 15997         Khan Agha  32.6475   65.9407             1
# 15998       Dashti Qala  37.2216   69.4975             2
# 15999          Dur Baba  34.0397   70.9300             2
# 16000             Rodat  34.2720   70.5679             2
#
#                                             source   source_scale  \
# 10000                               Voice of Jihad          Other
# 10001                               Voice of Jihad          Other
# 10002                               Voice of Jihad          Other
# 10003  Afghan Islamic Press News Agency; TOLO News       National
# 10004                               New York Times  International
# ...                                            ...            ...
# 15996                   Afghan Ministry of Defense          Other
# 15997                   Afghan Ministry of Defense          Other
# 15998                                       Xinhua  International
# 15999                          Bakhtar News Agency       National
# 16000                          Bakhtar News Agency       National
#
#                                                    notes  fatalities
# 10000  Reported on 11 July 2019, Taliban militants at...           0
# 10001  Reported on 11 July 2019, a bomb planted by Ta...           0
# 10002  Reported on 11 July 2019, Taliban militants at...           0
# 10003  On 11 July 2019, clashes between Taliban milit...           0
# 10004  On July 11 2019, 1 policeman was killed and 1 ...           1
# ...                                                  ...         ...
# 15996  As reported on Jan 2, over the past 24 hours, ...           2
# 15997  As reported on Jan 2, over the past 24 hours, ...           8
# 15998  On 01-January-2019, it was reported that 2 Afg...           5
# 15999  On 01-January-2019, 13 Islamic State and Talib...           5
# 16000  On 01-January-2019, 13 Islamic State and Talib...           4
#
# [6001 rows x 25 columns]

# %%
#   Group events by day into a new data frame.
# lesson code to mimic:
#    boro_df[['geog_region', 'boro_population']].groupby(['geog_region']).sum()
#    First we identify the columns we want to get, then, after groupby, 
#    we identify the column on which to group, then the method .sum()
days_fatalities_df=df[['event_date','fatalities']].groupby(['event_date']).sum()

days_fatalities_df.head(4)
# Out:
#             fatalities
# event_date
# 2019-01-01         154
# 2019-01-02          80
# 2019-01-03          79
# 2019-01-04          94

# %%
days_events_df=df[['event_date','fatalities']].groupby(['event_date']).count()

days_events_df.head(4)
# Out:
#             fatalities
# event_date
# 2019-01-01          33
# 2019-01-02          28
# 2019-01-03          40
# 2019-01-04          23

# %%
#   Group events by day into a new data frame.
# lesson code to mimic:
#    boro_df[['geog_region', 'boro_population']].groupby(['geog_region']).sum()
#    First we identify the columns we want to get, then, after groupby, 
#    we identify the column on which to group, then the method .sum()
days_df=df[['event_date','fatalities']].groupby(['event_date']).sum()
days_df.head(4)
# Out:
#             fatalities
# event_date
# 2019-01-01         154
# 2019-01-02          80
# 2019-01-03          79
# 2019-01-04          94

# %%
#danny code for doing a rolling average.  Id that NaN ok?
# days_df['rolling'] = days_df['fatalities'].rolling(30).mean()
# days_df.head(4)
# Out:
#             fatalities  rolling
# event_date
# 2019-01-01         154      NaN
# 2019-01-02          80      NaN
# 2019-01-03          79      NaN
# 2019-01-04          94      NaN

# %% [markdown]
# #### (Optional) Do any additional or other Plots in cell(s) below;

# %%
# make sure to wait a while
days_fatalities_df['fatalities'].plot(kind='hist');
### your optional code here
### your optional code here

# %%
# roger's plot of fatalities by day
days_fatalities_df['fatalities'].plot(kind='bar', \
    title='Fatalities by day per ACLED',
    use_index=False  # True for Use index as ticks for x axis. 
    #  xticks=df['event_date'] \  
    );

# %%
# roger's plot of fatalities by day
days_fatalities_df['fatalities'].plot(kind='line');

# %%
df.hist(column=['fatalities'], figsize=(12, 8));

# %% [markdown]
# # 4. Map your Data
#
# #### Create GeoDataFrame Map  `.plot()` to see our the spatial distribution of your data
#
# For this, please **add argument** `figsize=(10, 10)` inside our `.plot( )` function.
#
# * Add a title to your `plt` as well. _Hint `plt.title(...)`.

# %%
### your code here
### your code here
### your code here

# %% [markdown]
# #### (Optional) Do any additional or other Maps in cell(s) below;

# %%
### your optional code here
### your optional code here
### your optional code here

# %% [markdown]
# # 5. Highlight any interesting findings
#
# If there's any interesting summary statistics or findings or plots in a few key bullet points below, list some interesting notes about your data.
#
# Examples
# * My data is not normally distributed.
# * Over 50% of my values for column X are missing values.
# * I have suspicious outliers in my data
# * There appears to be some Geographic Distribution or pattern in your data.
# * Variable X appears to be correlated with Variable Y (statistical test(s) not required).

# %% [markdown]
# # 6. Present
#
# This will be done in class, you'll need to present your Jupyter Notebook in class.
#
# **Present** your Exploratory Data Analysis to the class Monday 2020/04/13
#   - Required: Present your Notebook to the class - 5-7 minute presentation in class on Monday 2020/04/13.
#   - No need for Powerpoint or Slides, you'll present your Notebook.
